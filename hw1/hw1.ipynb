# %% [markdown]
# # STA 141B: Homework 1
#
# Fall 2018

# %% [markdown]
# ## Information
#
# After the colons (in the same line) please write just your first name, last name, and the 9 digit student ID number below.
#
# First Name:Zack
#
# Last Name: Liu
#
# Student ID: 915026153

# %% [markdown]
# ## Instructions
#
# We use a script that extracts your answers by looking for cells in between the cells containing the exercise statements.  So you
#
# - MUST add cells in between the exercise statements and add answers within them and
# - MUST NOT modify the existing cells, particularly not the problem statement
#
# To make markdown, please switch the cell type to markdown (from code) - you can hit 'm' when you are in command mode - and use the markdown language.  For a brief tutorial see: https://daringfireball.net/projects/markdown/syntax

# %% [markdown]
# ## Part 1: The Doomsday Algorithm
#
# The Doomsday algorithm, devised by mathematician J. H. Conway, computes the day of the week any given date fell on. The algorithm is designed to be simple enough to memorize and use for mental calculation.
#
# __Example.__ With the algorithm, we can compute that July 4, 1776 (the day the United States declared independence from Great Britain) was a Thursday.
#
# The algorithm is based on the fact that for any year, several dates always fall on the same day of the week, called the <em style="color:#F00">doomsday</em> for the year. These dates include 4/4, 6/6, 8/8, 10/10, and 12/12.
#
# __Example.__ The doomsday for 2016 is Monday, so in 2016 the dates above all fell on Mondays. The doomsday for 2017 is Tuesday, so in 2017 the dates above will all fall on Tuesdays.
#
# The doomsday algorithm has three major steps:
#
# 1. Compute the anchor day for the target century.
# 2. Compute the doomsday for the target year based on the anchor day.
# 3. Determine the day of week for the target date by counting the number of days to the nearest doomsday.
#
# Each step is explained in detail below.

# %% [markdown]
# ### The Anchor Day
#
# The doomsday for the first year in a century is called the <em style="color:#F00">anchor day</em> for that century. The anchor day is needed to compute the doomsday for any other year in that century. The anchor day for a century $c$ can be computed with the formula:
# $$
# a = \bigl( 5 (c \bmod 4) + 2 \bigr) \bmod 7
# $$
# The result $a$ corresponds to a day of the week, starting with $0$ for Sunday and ending with $6$ for Saturday.
#
# __Note.__ The modulo operation $(x \bmod y)$ finds the remainder after dividing $x$ by $y$. For instance, $12 \bmod 3 = 0$ since the remainder after dividing $12$ by $3$ is $0$. Similarly, $11 \bmod 7 = 4$, since the remainder after dividing $11$ by $7$ is $4$.
#
# __Example.__ Suppose the target year is 1954, so the century is $c = 19$. Plugging this into the formula gives
# $$a = \bigl( 5 (19 \bmod 4) + 2 \bigr) \bmod 7 = \bigl( 5(3) + 2 \bigr) \bmod 7 = 3.$$
# In other words, the anchor day for 1900-1999 is Wednesday, which is also the doomsday for 1900.
#
# __Exercise 1.1.__ Write a function that accepts a year as input and computes the anchor day for that year's century. The modulo operator `%` and integer division `\\` will be useful. Document your function with a docstring and test your function for a few different years.

# %%
def get_achor_day(year):
    """The fucntion returns the anchor day for the year's century"""
    #get century of the year and find the anchor day
    century=year//100
    day=(5*(century%4)+2)%7
    return day

#testing
print(get_achor_day(2010))
print(get_achor_day(2018))
print(get_achor_day(1999))
print(get_achor_day(1888))
# Out:
# 2
# 2
# 3
# 5

# %% [markdown]
# ### The Doomsday
#
# Once the anchor day is known, let $y$ be the last two digits of the target year. Then the doomsday for the target year can be computed with the formula:
# $$d = \left(y + \left\lfloor\frac{y}{4}\right\rfloor + a\right) \bmod 7$$
# The result $d$ corresponds to a day of the week.
#
# __Note.__ The floor operation $\lfloor x \rfloor$ rounds $x$ down to the nearest integer. For instance, $\lfloor 3.1 \rfloor = 3$ and $\lfloor 3.8 \rfloor = 3$.
#
# __Example.__ Again suppose the target year is 1954. Then the anchor day is $a = 3$, and $y = 54$, so the formula gives
# $$
# d = \left(54 + \left\lfloor\frac{54}{4}\right\rfloor + 3\right) \bmod 7 = (54 + 13 + 3) \bmod 7 = 0.
# $$
# Thus the doomsday for 1954 is Sunday.
#
# __Exercise 1.2.__ Write a function that accepts a year as input and computes the doomsday for that year. Your function may need to call the function you wrote in exercise 1.1. Make sure to document and test your function.

# %%
#import floor from math.py
from math import floor

#function
def get_doomsday(year):
    """The function returns the doomsday of the year"""
    #get the achor day
    a=get_achor_day(year)
    #get last two digits of the year
    y=year%100
    #get the doomsday
    d=(y+floor(y/4)+a)%7
    return d

#testing
print(get_doomsday(2016))
print(get_doomsday(1815))
# Out:
# 1
# 2

# %% [markdown]
# ### The Day of Week
#
# The final step in the Doomsday algorithm is to count the number of days between the target date and a nearby doomsday, modulo 7. This gives the day of the week.
#
# Every month has at least one doomsday:
# * (regular years) 1/10, 2/28
# * (leap years) 1/11, 2/29
# * 3/21, 4/4, 5/9, 6/6, 7/11, 8/8, 9/5, 10/10, 11/7, 12/12
#
# __Example.__ Suppose we want to find the day of the week for 7/21/1954. The doomsday for 1954 is Sunday, and a nearby doomsday is 7/11. There are 10 days in July between 7/11 and 7/21. Since $10 \bmod 7 = 3$, the date 7/21/1954 falls 3 days after a Sunday, on a Wednesday.
#
# __Exercise 1.3.__ Write a function to determine the day of the week for a given day, month, and year. Be careful of leap years! Your function should return a string such as "Thursday" rather than a number. As usual, document and test your code.

# %%
def day_of_week(m,d,y):
    """The function returns the day of the week for a given day"""
    #store the day of the week in a list
    dow=["Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday"]
    
    #store the dommsday in each month for regualr and leap year into two lists
    #First element 0 in each list is a place holder 
    regular=[0,10,28,21,4,9,6,11,8,5,10,7,12]
    leap=[0,11,29,21,4,9,6,11,8,5,10,7,12]
    
    #determine whether a year is regular or leap
    #True means regular , False means leap
    regular_or_leap= (y%4!=0 or(y%100==0 and y%400!=0))
    
    #get the doomsday of the year    
    doomsday=get_doomsday(y)

    #get the day of the week for the given day
    if regular_or_leap:
        day_index=(doomsday+(d-regular[m])%7)%7
    else:
        day_index=(doomsday+(d-leap[m])%7)%7

    return dow[day_index]

#testing
print(day_of_week(11,3,2000))
print(day_of_week(7,21,1954))
print(day_of_week(12,1,1888))
# Out:
# Friday
# Wednesday
# Saturday

# %% [markdown]
# __Exercise 1.4.__ Davis picks up yard waste on the first Monday of the month.  How many times did the 1st of the month (first day of the month) fall on a Monday in the years 2000-2016 (including 2016)?

# %%
#set a counter 
times=0
#loop over years and months 
for year in range(2000,2017):
    #accumulate counter times when the 1st of each month fall on Monday
    times+=sum([1 for month in range(1,13) if day_of_week(month,1,year)=="Monday"])
times
# Out:
# 28

# %% [markdown]
# There are 28 times such that 1st of the month falls on a Monday.

# %% [markdown]
# ## Part 2: 1978 Birthdays
#
# __Exercise 2.1.__ The file `birthdays.txt` contains the number of births in the United States for each day in 1978. Inspect the file to determine the format. Note that columns are separated by the tab character, which can be entered in Python as `\t`. Write a function that uses iterators and list comprehensions with the string methods `split()` and `strip()` to  convert each line of data to the tuple format
#
# ```Python
# (month, day, year, count)
# ```
# The elements of this list should be integers, not strings.  Read in the data and create this list of tuples.

# %%
# a sub-function used in list_brithdays to load data.
def read_birthdays():
    """The function read in the birthdays.txt and store the information into a list"""
    with open("birthdays.txt") as file:
        #load data into a list without unneccessary lines 
        birthday=[line.strip() for i, line in enumerate(file) if i >5]
        birthday=[line for line in birthday if line !='']
    return birthday

#convert each line of data to the tuple format  
def list_birthdays():
    """The function converts each line of data to the tuple format and store into a list"""
    #read in birthdays.txt
    birthdays=read_birthdays()
    #separate day and count and strip out "/" and "\t"
    #use map to convert strings into integers, and store each line into a tuple
    day_count=[(*map(int,line.split("\t")[0].split("/")),int(line.split("\t")[1])) for line in birthdays]    
    return day_count


list_birthdays()
# Out:
# [(1, 1, 78, 7701),
#  (1, 2, 78, 7527),
#  (1, 3, 78, 8825),
#  (1, 4, 78, 8859),
#  (1, 5, 78, 9043),
#  (1, 6, 78, 9208),
#  (1, 7, 78, 8084),
#  (1, 8, 78, 7611),
#  (1, 9, 78, 9172),
#  (1, 10, 78, 9089),
#  (1, 11, 78, 9210),
#  (1, 12, 78, 9259),
#  (1, 13, 78, 9138),
#  (1, 14, 78, 8299),
#  (1, 15, 78, 7771),
#  (1, 16, 78, 9458),
#  (1, 17, 78, 9339),
#  (1, 18, 78, 9120),
#  (1, 19, 78, 9226),
#  (1, 20, 78, 9305),
#  (1, 21, 78, 7954),
#  (1, 22, 78, 7560),
#  (1, 23, 78, 9252),
#  (1, 24, 78, 9416),
#  (1, 25, 78, 9090),
#  (1, 26, 78, 9387),
#  (1, 27, 78, 8983),
#  (1, 28, 78, 7946),
#  (1, 29, 78, 7527),
#  (1, 30, 78, 9184),
#  (1, 31, 78, 9152),
#  (2, 1, 78, 9159),
#  (2, 2, 78, 9218),
#  (2, 3, 78, 9167),
#  (2, 4, 78, 8065),
#  (2, 5, 78, 7804),
#  (2, 6, 78, 9225),
#  (2, 7, 78, 9328),
#  (2, 8, 78, 9139),
#  (2, 9, 78, 9247),
#  (2, 10, 78, 9527),
#  (2, 11, 78, 8144),
#  (2, 12, 78, 7950),
#  (2, 13, 78, 8966),
#  (2, 14, 78, 9859),
#  (2, 15, 78, 9285),
# ...

# %% [markdown]
# __Exercise 2.2.__
#
# 1. Count the number of birthdays by the month (number of birthdays per month).
# 2. Count the number of birthdays by the day of the week.
#
# What conclusions can you draw? You may find the `Counter` class in the `collections` module useful.

# %%
#import defaultdict
from collections import defaultdict

#load data
birthday_count=list_birthdays()

#store months into a list
months_string=["January","Feburary","March","Aprill","May","June", \
       "July","August","September","October", "Novemenber","December"]

#create a default dictionary to store # of birthdays by month
count_by_month=defaultdict(int)
for line in birthday_count:
    count_by_month[months_string[line[0]-1]]+=line[3]



#convert the day of each birthday into the day of the week and store into a list with the counts 
dow_birthday_count=[(day_of_week(line[0],line[1],1900+line[2]),line[3]) for  line in birthday_count]

#store # of birthdays by the day of the week in a default dictionary
count_by_dow=defaultdict(int)
for line in dow_birthday_count:
    count_by_dow[line[0]]+=line[1]

#print out results
print(count_by_month)
print(count_by_dow)
# Out:
# defaultdict(<class 'int'>, {'January': 270695, 'Feburary': 249875, 'March': 276584, 'Aprill': 254577, 'May': 270812, 'June': 270756, 'July': 294701, 'August': 302795, 'September': 293891, 'October': 288955, 'Novemenber': 274671, 'December': 284927})
# defaultdict(<class 'int'>, {'Sunday': 421400, 'Monday': 487309, 'Tuesday': 504858, 'Wednesday': 493897, 'Thursday': 493149, 'Friday': 500541, 'Saturday': 432085})

# %% [markdown]
# ## Conclusion
# * August and Tuesday have the largest brith rates relatively!
